# %% [markdown]
# # Run level 2A and 2B pipelines on LRS-SLIT data using jwst.pipeline classes

# %% [markdown]
# ### by Patrick Kavanagh (DIAS, Ireland) June 28th 2017

# %% [markdown]
# This notebook demonstrates the execution of the level 2A and 2B pipelines for LRS-SLIT data in Python using the jwst.pipeline classes.
#
# For a description of the pipeline classes see:
#
# http://ssb.stsci.edu/doc/jwst_dev/jwst/pipeline/index.html
#
# The files used in this notebook is a MIRISim simulation of a point source with a blackbody spectrum plus emission lines. One file represents the on-source observation, while the second is an off-source observation which will be subtracted from the on-source observation.

# %% [markdown]
# #### Imports

# %%
import os, glob, shutil

import numpy as np
from astropy.io import fits
from matplotlib.colors import LogNorm
import matplotlib.pyplot as plt
from subprocess import call

from jwst import datamodels

# %matplotlib inline
# %matplotlib notebook # if you want interactive plots

# %% [markdown]
# #### Set input file:

# %%
# set input filenames and directory. In this example, the files are located in a folder called 'LRS-SLIT_demo_data'
input_dir = 'LRS-SLIT_demo_data'
input_files = glob.glob(os.path.join(input_dir,'*.fits'))

# set the output directory name
output_dir = input_dir + '_pipelined'

# if the output directory exists, delete it
if os.path.exists(output_dir): shutil.rmtree(output_dir)

# create the output directory
os.mkdir(output_dir)

# %% [markdown]
# #### print some information about the input files. We will just look at the first file

# %%
# print some info on input file
with fits.open(input_files[0]) as hdulist:
        
    if hdulist[0].header['ORIGIN'] == 'STScI':
        # specific information on instrument/exposure
        identifier = hdulist[0].header['OBS_ID']
        detector = hdulist[0].header['EXP_TYPE']
        im_filter = hdulist[0].header['FILTER']
        nInts = hdulist[0].header['NINTS']
        nGroups = hdulist[0].header['NGROUPS']
        readPatt = hdulist[0].header['READPATT']
        expTime = hdulist[0].header['EFFEXPTM']
        subArr = hdulist[0].header['SUBARRAY']
        channel = hdulist[0].header['CHANNEL']
        band = hdulist[0].header['BAND']
        print "ID\t\t\t Detector\t Filter\t subAr\t nInts\t nGrps\t rdPatt\t ExpTime (s)"
        print "--------------------------------------------------------------------------------------------------"
        print "%s\t %s\t %s\t %s\t %d\t %d\t %s\t %0.1f" % (identifier,detector,im_filter,subArr,nInts,nGroups,readPatt,expTime)
        print "\n\n"
            
    else:
        # specific information on instrument/exposure
        detector = hdulist[0].header['EXP_TYPE']
        im_filter = hdulist[0].header['FILTER']
        nInts = hdulist[0].header['NINTS']
        nGroups = hdulist[0].header['NGROUPS']
        readPatt = hdulist[0].header['READPATT']
        expTime = hdulist[0].header['EFFEXPTM']
        subArr = hdulist[0].header['SUBARRAY']
        print "ID\t Type\t\t\t Filter\t subAr\t nInts\t nGrps\t rdPatt\t ExpTime (s)"
        print "--------------------------------------------------------------------------------------------------"
        print "MIRISim\t %s\t %s\t %s\t %d\t %d\t %s\t %0.1f" % (detector,im_filter,subArr, nInts,nGroups,readPatt,expTime)
        print "\n\n"

    # fits extension table
    hdulist.info()
# Out:
# ID	 Type			 Filter	 subAr	 nInts	 nGrps	 rdPatt	 ExpTime (s)
# --------------------------------------------------------------------------------------------------
# MIRISim	 MIR_LRS-FIXEDSLIT	 P750L	 FULL	 2	 50	 FAST	 277.5
#
#
#
# Filename: LRS-SLIT_demo_data/det_image_1_MIRIMAGE_P750Lexp1.fits
# No.    Name         Type      Cards   Dimensions   Format
#   0  PRIMARY     PrimaryHDU     144   ()
#   1  SCI         ImageHDU        14   (1032, 1024, 50, 2)   float32
#   2  REFOUT      ImageHDU        14   (258, 1024, 50, 2)   float32
#   3  PIXELDQ     ImageHDU        10   (1032, 1024)   int32 (rescales to uint32)
#   4  PIXELDQ_DEF  BinTableHDU     17   29R x 4C   [J, J, 40A, 128A]
#   5  ASDF        ImageHDU         7   (533678773,)   uint8

# %% [markdown]
# #### show the last frame of the first integration for each file

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 12))
axs = axs.ravel()

i = 0
for input_file in input_files:
    # open the input image as a jwst data model
    with datamodels.open(input_file) as in_dm:

        dith_num = i+1
        axs[i].imshow(in_dm.data[0,-1,:,:], cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=1e4,vmax=5e4))
        axs[i].annotate('Nod %d' % dith_num, xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
        axs[i].set_facecolor('black')
        i += 1

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Level 2A pipeline (ramps-to-slopes)

# %% [markdown]
# #### import the level 2A pipeline class and print description

# %%
from jwst.pipeline import SloperPipeline
print SloperPipeline.__doc__
# Out:
#     SloperPipeline: Apply all calibration steps to raw JWST
#     ramps to produce a 2-D slope product. Included steps are:
#     group_scale, dq_init, saturation, ipc, superbias, refpix, rscd,
#     lastframe, linearity, dark_current, persistence, jump detection,
#     and ramp_fit.

# %% [markdown]
# For MIRI, the steps in order are: dq_init, saturation, linearity, RSCD, lastframe, dark_current, refpix, jump, ramp_fitting
#
# NOTE: As dark current was switched off in the MIRISim simulations, we will skip the dark_current step in the call to the SloperPipeline

# %% [markdown]
# #### run pipeline
# The output of the level 2A pipeline is contained in the dm_2A data model, which we add to a model container. This s also saved to a fits file ending in '_rate.fits'. Saving the fits file is optional

# %%
dm_2A_container = datamodels.ModelContainer()
for input_file in input_files:
    dm_2A = SloperPipeline.call(input_file, save_results=True, output_dir=output_dir, steps={'dark_current':{'skip':True}})
    dm_2A_container.append(dm_2A)
# Out:
# 2017-06-29 07:19:55,185 - stpipe.SloperPipeline - INFO - SloperPipeline instance created.
# 2017-06-29 07:19:55,186 - stpipe.SloperPipeline.group_scale - INFO - GroupScaleStep instance created.
# 2017-06-29 07:19:55,187 - stpipe.SloperPipeline.saturation - INFO - SaturationStep instance created.
# 2017-06-29 07:19:55,189 - stpipe.SloperPipeline.rscd - INFO - RSCD_Step instance created.
# 2017-06-29 07:19:55,190 - stpipe.SloperPipeline.ipc - INFO - IPCStep instance created.
# 2017-06-29 07:19:55,192 - stpipe.SloperPipeline.ramp_fit - INFO - RampFitStep instance created.
# 2017
- stpipe.SloperPipeline.jump - INFO - Step jump running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x118db26d0>,).
# 2017-06-29 07:31:28,452 - stpipe.SloperPipeline.jump - INFO - CR rejection threshold = 4 sigma
# 2017-06-29 07:31:29,958 - stpipe.SloperPipeline.jump - INFO - Using GAIN reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0008.fits
# 2017-06-29 07:31:31,338 - stpipe.SloperPipeline.jump - INFO - Using READNOISE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0040.fits
# 2017-06-29 07:31:32,586 - stpipe.SloperPipeline.jump - INFO - Executing two-point difference method
# 2017-06-29 07:31:51,038 - stpipe.SloperPipeline.jump - INFO - Step jump done
# 2017-06-29 07:31:54,709 - stpipe.SloperPipeline.ramp_fit - INFO - Prefetch for GAIN reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0008.fits'.
# 2017-06-29 07:31:54,710 - stpipe.SloperPipeline.ramp_fit - INFO - Prefetch for READNOISE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0040.fits'.
# 2017-06-29 07:31:54,905 - stpipe.SloperPipeline.ramp_fit - INFO - Step ramp_fit running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x1692b25d0>,).
# 2017-06-29 07:31:58,742 - stpipe.SloperPipeline.ramp_fit - INFO - Using READNOISE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0040.fits
# 2017-06-29 07:31:58,781 - stpipe.SloperPipeline.ramp_fit - INFO - Using GAIN reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0008.fits
# 2017-06-29 07:31:58,810 - stpipe.SloperPipeline.ramp_fit - INFO - Using algorithm = ols
# 2017-06-29 07:31:58,811 - stpipe.SloperPipeline.ramp_fit - INFO - Using weighting = optimal
# 2017-06-29 07:31:58,829 - stpipe.SloperPipeline.ramp_fit - INFO - Effective integration time per group: 2.77504
# 2017-06-29 07:35:16,002 - stpipe.SloperPipeline.ramp_fit - INFO - Number of groups per integration: 50
# 2017-06-29 07:35:16,003 - stpipe.SloperPipeline.ramp_fit - INFO - Number of integrations: 2
# 2017-06-29 07:35:16,298 - stpipe.SloperPipeline.ramp_fit - INFO - Step ramp_fit done
# 2017-06-29 07:35:16,299 - stpipe.SloperPipeline - INFO - ... ending calwebb_sloper
# 2017-06-29 07:35:16,305 - stpipe.SloperPipeline - INFO - Saving file LRS-SLIT_demo_data_pipelined/det_image_2_MIRIMAGE_P750Lexp1_rate.fits
# 2017-06-29 07:35:16,420 - stpipe.SloperPipeline - INFO - Step SloperPipeline done

# %% [markdown]
# #### quick check of output. We'll look at the first dither

# %%
# check the calibration step information
print'Check step information status:'
print 'dq_init: %s' % dm_2A_container[0].meta.cal_step.dq_init
print 'saturation: %s' % dm_2A_container[0].meta.cal_step.saturation
print 'linearity: %s' % dm_2A_container[0].meta.cal_step.linearity
print 'rscd: %s' % dm_2A_container[0].meta.cal_step.rscd
print 'lastframe: %s' % dm_2A_container[0].meta.cal_step.lastframe
print 'dark_current: %s' % dm_2A_container[0].meta.cal_step.dark_sub
print 'refpix: %s' % dm_2A_container[0].meta.cal_step.refpix
print 'jump: %s' % dm_2A_container[0].meta.cal_step.jump
print 'ramp_fit: %s' % dm_2A_container[0].meta.cal_step.ramp_fit
# Out:
# Check step information status:
# dq_init: COMPLETE
# saturation: COMPLETE
# linearity: COMPLETE
# rscd: COMPLETE
# lastframe: COMPLETE
# dark_current: None
# refpix: COMPLETE
# jump: COMPLETE
# ramp_fit: COMPLETE

# %% [markdown]
# ### Level 2B pipeline

# %% [markdown]
# #### import the level 2B pipeline class and print description

# %%
from jwst.pipeline import Spec2Pipeline
print Spec2Pipeline.__doc__
# Out:
#     Spec2Pipeline: Processes JWST spectroscopic exposures from Level 2a to 2b.
#     Accepts a single exposure or an association as input.
#
#     Included steps are:
#     assign_wcs, background subtraction, NIRSpec MSA imprint subtraction,
#     NIRSpec MSA bad shutter flagging, 2-D subwindow extraction, flat field,
#     source type decision, straylight, fringe, pathloss, photom, resample_spec,
#     cube_build, and extract_1d.

# %% [markdown]
# For the LRS, the level 2B steps in order are: assign_wcs, bkg_subtract, flat_field, srctype, photom, cube_build, extract_1d
#
# The bkg_subtract subtract step requires an association file defining the source and background exposures. At the moment, there is no easy way to create one, so we define it manually in a cell and write to the association json file.

# %%
import json

data = {
    "asn_rule": "Asn_Lv2Spec",
    "asn_pool": "dummy_pool",
    "program": "00000",
    "asn_type": "spec2",
    "products": [
        {
            "name": "lrs_bgsub",
            "members": [
                {
                    "expname": "LRS-SLIT_demo_data_pipelined/det_image_1_MIRIMAGE_P750Lexp1_rate.fits",
                    "exptype": "science"
                },
                {
                    "expname": "LRS-SLIT_demo_data_pipelined/det_image_2_MIRIMAGE_P750Lexp1_rate.fits",
                    "exptype": "background"
                }
            ]
        }
    ]
}

with open('LRS_bg-sub_lvl2_asn.json', 'w') as outfile:  
    json.dump(data, outfile)

# %% [markdown]
# #### run pipeline
# We pass the level 2 assocation file. The output is contained in the dm_2B data model and saved to a fits file ending in '_bgsub_cal.fits'. Saving this fits file is optional. A 1D spectrum is also saved (see below).

# %%
dm_2B = Spec2Pipeline.call('LRS_bg-sub_lvl2_asn.json', save_results=True, output_dir=output_dir, steps={'extract_1d':{'save_results':True}})
# Out:
# 2017-06-29 07:54:17,045 - stpipe.Spec2Pipeline - INFO - Spec2Pipeline instance created.
# 2017-06-29 07:54:17,046 - stpipe.Spec2Pipeline.pathloss - INFO - PathLossStep instance created.
# 2017-06-29 07:54:17,048 - stpipe.Spec2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# 2017-06-29 07:54:17,049 - stpipe.Spec2Pipeline.imprint_subtract - INFO - ImprintStep instance created.
# 2017-06-29 07:54:17,051 - stpipe.Spec2Pipeline.photom - INFO - PhotomStep instance created.
# 2017-06-29 07:54:17,053 - stpipe.Spec2Pipeline.resample_spec - INFO - ResampleSpecStep instance created.
# 2017-06-29 07:54:17,055 - stpipe.Spec2Pipeline.cube_build - INFO - CubeBuildStep instance created.
# 2017-06-29 07:54:17,058 - stpipe.Spec2Pipeline.straylight - INFO - StraylightStep instance created.
# 2017-06-29 07:54:17,059 - stpipe.Spec2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# 2017-06-29 07:54:17,061 - stpipe.Spec2Pipeline.extract_2d - INFO - Extract2dStep instance created.
# 2017-06-29 07:54:17,062 - stpipe.Spec2Pipeline.fringe - INFO - FringeStep instance created.
# 2017-06-29 07:54:17,063 - stpipe.Spec2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# 2017-06-29 07:54:17,065 - stpipe.Spec2Pipeline.srctype - INFO - SourceTypeStep instance created.
# 2017-06-29 07:54:17,067 - stpipe.Spec2Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2017-06-29 07:54:17,559 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline running with args ('LRS_bg-sub_lvl2_asn.json',).
# 2017-06-29 07:54:17,560 - stpipe.Spec2Pipeline - INFO - Starting calwebb_spec2 ...
# 2017-06-29 07:54:17,567 - stpipe.Spec2Pipeline - INFO - Processing product lrs_bgsub
# 2017-06-29 07:54:17,568 - stpipe.Spec2Pipeline - INFO - Working on input LRS-SLIT_demo_data_pipelined/det_image_1_MIRIMAGE_P750Lexp1_rate.fits ...
# 2017-06-29 07:54:18,512 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2017-06-29 07:54:18,513 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2017-06-29 07:54:18,513 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2017-06-29 07:54:18,514 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for DISTORTION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0023.asdf'.
# 2017-06-29 07:54:18,515 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for FILTEROFFSET reference file is 'N/A'.
# 2017-06-29 07:54:18,516 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for FORE reference file is 'N/A'.
# 2017-06-29 07:54:18,517 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for FPA reference file is 'N/A'.
# 2017-06-29 07:54:18,518 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2017-06-29 07:54:18,519 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2017-06-29 07:54:18,519 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2017-06-29 07:54:18,520 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for MSA reference file is 'N/A'.
# 2017-06-29 07:54:18,521 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for OTE reference file is 'N/A'.
# 2017-06-29 07:54:18,522 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2017-06-29 07:54:18,523 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for SPECWCS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_specwcs_0001.fits'.
# 2017-06-29 07:54:18,524 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for V2V3 reference file is 'N/A'.
# 2017-06-29 07:54:18,525 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2017-06-29 07:54:18,612 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<jwst.datamodels.image.ImageModel object at 0x1765e3b10>,).
# 2017-06-29 07:54:27,008 - stpipe.Spec2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2017-06-29 07:54:27,040 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2017-06-29 07:54:27,299 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract running with args (<jwst.datamodels.image.ImageModel object at 0x119d03fd0>, ['LRS-SLIT_demo_data_pipelined/det_image_2_MIRIMAGE_P750Lexp1_rate.fits']).
# 2017-06-29 07:54:28,008 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract done
# 2017-06-29 07:54:28,821 - stpipe.Spec2Pipeline.flat_field - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2017-06-29 07:54:28,822 - stpipe.Spec2Pipeline.flat_field - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2017-06-29 07:54:28,823 - stpipe.Spec2Pipeline.flat_field - INFO - Prefetch for FLAT reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_flat_0244.fits'.
# 2017-06-29 07:54:28,824 - stpipe.Spec2Pipeline.flat_field - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2017-06-29 07:54:28,911 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field running with args (<jwst.datamodels.image.ImageModel object at 0x1765e3150>,).
# 2017-06-29 07:54:29,640 - stpipe.Spec2Pipeline.flat_field - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2017-06-29 07:54:29,641 - stpipe.Spec2Pipeline.flat_field - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2017-06-29 07:54:29,642 - stpipe.Spec2Pipeline.flat_field - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2017-06-29 07:54:29,648 - stpipe.Spec2Pipeline.flat_field - WARNING - Keyword DIFF_PATTERN does not correspond to an existing DQ mnemonic, so will be ignored
# 2017-06-29 07:54:29,832 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field done
# 2017-06-29 07:54:30,044 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype running with args (<jwst.datamodels.image.ImageModel object at 0x1765e3ed0>,).
# 2017-06-29 07:54:30,205 - stpipe.Spec2Pipeline.srctype - INFO - Input EXP_TYPE is MIR_LRS-FIXEDSLIT
# 2017-06-29 07:54:30,206 - stpipe.Spec2Pipeline.srctype - INFO - Input SRCTYPE is unknown. Setting to default value of POINT
# 2017-06-29 07:54:30,228 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype done
# 2017-06-29 07:54:30,953 - stpipe.Spec2Pipeline.photom - INFO - Prefetch for AREA reference file is 'N/A'.
# 2017-06-29 07:54:30,954 - stpipe.Spec2Pipeline.photom - INFO - Prefetch for PHOTOM reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_photom_0014.fits'.
# 2017-06-29 07:54:31,043 - stpipe.Spec2Pipeline.photom - INFO - Step photom running with args (<jwst.datamodels.image.ImageModel object at 0x1188bbf10>,).
# 2017-06-29 07:54:31,727 - stpipe.Spec2Pipeline.photom - INFO - Using photom reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_photom_0014.fits
# 2017-06-29 07:54:32,152 - stpipe.Spec2Pipeline.photom - INFO - Using area reference file: N/A
# 2017-06-29 07:54:32,154 - stpipe.Spec2Pipeline.photom - INFO - Using instrument: MIRI
# 2017-06-29 07:54:32,154 - stpipe.Spec2Pipeline.photom - INFO -  detector: MIRIMAGE
# 2017-06-29 07:54:32,155 - stpipe.Spec2Pipeline.photom - INFO -  exp_type: MIR_LRS-FIXEDSLIT
# 2017-06-29 07:54:32,156 - stpipe.Spec2Pipeline.photom - INFO -  filter: P750L
# 2017-06-29 07:54:32,212 - stpipe.Spec2Pipeline.photom - INFO -  subarray: FULL
# 2017-06-29 07:54:32,228 - stpipe.Spec2Pipeline.photom - INFO - Relative response table written.
# 2017-06-29 07:54:32,229 - stpipe.Spec2Pipeline.photom - INFO - Writing PHOTMJSR with value: 1
# 2017-06-29 07:54:32,253 - stpipe.Spec2Pipeline.photom - INFO - Step photom done
# 2017-06-29 07:54:32,938 - stpipe.Spec2Pipeline.extract_1d - INFO - Prefetch for EXTRACT1D reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0004.json'.
# 2017-06-29 07:54:33,014 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d running with args (<jwst.datamodels.image.ImageModel object at 0x119ca2c50>,).
# 2017-06-29 07:54:33,788 - stpipe.Spec2Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0004.json
# 2017-06-29 07:54:33,938 - stpipe.Spec2Pipeline.extract_1d - WARNING - 1 NaNs in wavelength array; set to 0.01
# 2017-06-29 07:54:33,969 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 388 elements were extrapolated; these values will be set to 1.
# 2017-06-29 07:54:34,206 - stpipe.Spec2Pipeline.extract_1d - INFO - Saving file LRS-SLIT_demo_data_pipelined/lrs_bgsub_x1d.fits
# 2017-06-29 07:54:34,291 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d done
# 2017-06-29 07:54:34,293 - stpipe.Spec2Pipeline - INFO - Finished processing product lrs_bgsub
# 2017-06-29 07:54:34,308 - stpipe.Spec2Pipeline - INFO - Ending calwebb_spec2
# 2017-06-29 07:54:34,336 - stpipe.Spec2Pipeline - INFO - Saving file LRS-SLIT_demo_data_pipelined/lrs_bgsub_cal.fits
# 2017-06-29 07:54:34,586 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline done

# %% [markdown]
# ### check of output
#
# The level 2B pipeline for the LRS-SLIT produces two files for each input:
#
# _bgsub_cal.fits - the background subtracted calibrated level 2B file
#
# _bgsub_x1d.fits - the background subtracted 1d spectrum
#
# We can have a look at each of these

# %%
# set the output file names
level2B_file = glob.glob(os.path.join(output_dir,'*_cal.fits'))[0]
spec_file = glob.glob(os.path.join(output_dir,'*_x1d.fits'))[0]

# %% [markdown]
# #### level 2B file

# %%
# check the calibration step information
print'Check step information status:'
print 'assign_wcs: %s' % dm_2B.meta.cal_step.assign_wcs
print 'bkg_subtract: %s' % dm_2B.meta.cal_step.back_sub
print 'flat_field: %s' % dm_2B.meta.cal_step.flat_field
print 'srctype: %s' % dm_2B.meta.cal_step.srctype
print 'photom: %s' % dm_2B.meta.cal_step.photom
# Out:
# Check step information status:
# assign_wcs: COMPLETE
# bkg_subtract: COMPLETE
# flat_field: COMPLETE
# srctype: COMPLETE
# photom: COMPLETE

# %% [markdown]
# #### calibrated image

# %%
# open the input image as a jwst data model
with datamodels.open(input_files[0]) as in_dm:
    with datamodels.open(level2B_file) as out_dm:
        
        # plot--------------------------------------
        # show the input ramp image and the calibrated
        # slope image. Note the user may have to adjust
        # the scale parameters
        fig, axs = plt.subplots(1, 2, figsize=(12, 6))

        # sum the groups in the first integration of the input ramp image and plot
        axs[0].imshow(in_dm.data[0,-1,:,:], cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=9e3,vmax=2e4))
        axs[0].annotate('Input ramp image', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
        axs[0].set_facecolor('black')
        axs[1].imshow(out_dm.data, cmap='jet', interpolation='nearest', origin='lower', vmin=-1, vmax=100)
        axs[1].annotate('Calibrated slope image', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
        axs[1].set_facecolor('black')

        plt.tight_layout()
        plt.show()

# %% [markdown]
# #### 1D spectrum

# %%
from jwst.datamodels import SpecModel

# open the spectrum as a jwst data model
with SpecModel(spec_file) as spec_dm:
    # plot--------------------------------------
    # simple XY plot of the spectrum
    fig, axs = plt.subplots(1, 1, figsize=(8, 6))

    # plot the spectrum in the channel 2 wavelength range
    axs.plot(spec_dm.spec_table['WAVELENGTH'][1:-1], spec_dm.spec_table['FLUX'][1:-1], c='b', marker='.', markersize=3, linestyle='-', linewidth=2)
    axs.set_ylabel(r'Flux ($\mu$Jy)')
    axs.set_xlabel(r'Wavelength ($\mu$m)')
    axs.set_xlim(4.9,14.)
    #axs.set_ylim(0,6000)
    plt.show()
